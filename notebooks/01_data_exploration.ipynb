# %% [markdown]
# # 📊 NFL Player Trajectory Prediction - Data Exploration
#
# **目标**：理解数据结构，发现关键模式，为特征工程做准备
#
# ---
#
# ## 📋 本 Notebook 的内容
#
# 1. **数据加载与概览**
# 2. **数据结构分析**
# 3. **核心可视化**
#    - 球员位置分布
#    - 球落点与接球手距离
#    - 速度和加速度分析
# 4. **关键洞察（Insights）**
#
# ---
